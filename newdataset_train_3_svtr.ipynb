# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python -m pip install paddlepaddle-gpu==2.4.1.post112 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# %cd /content/PaddleOCR
# !pip install -r requirements.txt

# %%
# !mkdir pretrained_model
# %cd pretrained_model/
# !wget https://paddleocr.bj.bcebos.com/PP-OCRv3/multilingual/arabic_PP-OCRv3_rec_train.tar
#!wget https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/rec_r34_vd_none_bilstm_ctc_v2.0_train.tar
# !tar -xf arabic_PP-OCRv3_rec_train.tar && rm -rf arabic_PP-OCRv3_rec_train.tar
#!tar -xf rec_r34_vd_none_bilstm_ctc_v2.0_train.tar && rm -rf rec_r34_vd_none_bilstm_ctc_v2.0_train.tar

# %%
# !rm -rf /content/drive/MyDrive/MY_dataset
# !rm -rf /content/drive/MyDrive/output_my_dataset

# %%
# !rm -rf /content/PaddleOCR/train_data

# %%
# !unzip /content/drive/MyDrive/MY_dataset.zip -d /content/drive/MyDrive

# %%
# !mkdir /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/MY_dataset/Train -r /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/MY_dataset/val -r /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/MY_dataset/Test -r /content/PaddleOCR/train_data

# %%
# !cp /content/drive/MyDrive/MY_dataset/Train.txt -r /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/MY_dataset/val.txt -r /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/MY_dataset/Test.txt -r /content/PaddleOCR/train_data

# %%
import cv2 
import os 
#from imutils import perspective
import numpy as np 
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
from imutils import perspective

# %%
# %cd /content/PaddleOCR
# Out:
# /content/PaddleOCR

# %% [markdown]
# #Train dataset

# %%
# !python3 tools/train.py -c /content/drive/MyDrive/MY_dataset/config.yml -o Global.pretrained_model=/content/PaddleOCR/pretrained_model/arabic_PP-OCRv3_rec_train/best_accuracy

# %% [markdown]
# #continue trained model

# %%
# !python3 tools/train.py -c /content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/config.yml -o Global.checkpoints=/content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/latest
# Out:
# [2023/02/21 14:01:29] ppocr INFO: Architecture :
# [2023/02/21 14:01:29] ppocr INFO:     Backbone :
# [2023/02/21 14:01:29] ppocr INFO:         last_conv_stride : [1, 2]
# [2023/02/21 14:01:29] ppocr INFO:         last_pool_type : avg
# [2023/02/21 14:01:29] ppocr INFO:         name : MobileNetV1Enhance
# [2023/02/21 14:01:29] ppocr INFO:         scale : 0.5
# [2023/02/21 14:01:29] ppocr INFO:     Head :
# [2023/02/21 14:01:29] ppocr INFO:         head_list :
# [2023/02/21 14:01:29] ppocr INFO:             CTCHead :
# [2023/02/21 14:01:29] ppocr INFO:                 Head :
# [2023/02/21 14:01:29] ppocr INFO:                     fc_decay : 1e-05
# [2023/02/21 14:01:29] ppocr INFO:                 Neck :
# [2023/02/21 14:01:29] ppocr INFO:                     depth : 2
# [2023/02/21 14:01:29] ppocr INFO:                     dims : 64
# [2023/02/21 14:01:29] ppocr INFO:                     hidden_dims : 120
# [2023/02/21 14:01:29] ppocr INFO:                     name : svtr
# ...

# %% [markdown]
# #**evaluate new-dataset**

# %%
# !python3 -m paddle.distributed.launch --gpus '0' tools/eval.py -c /content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/config.yml -o Global.checkpoints=/content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/best_accuracy
# Out:
# LAUNCH INFO 2023-02-18 12:54:26,012 -----------  Configuration  ----------------------
# LAUNCH INFO 2023-02-18 12:54:26,012 devices: 0
# LAUNCH INFO 2023-02-18 12:54:26,013 elastic_level: -1
# LAUNCH INFO 2023-02-18 12:54:26,013 elastic_timeout: 30
# LAUNCH INFO 2023-02-18 12:54:26,013 gloo_port: 6767
# LAUNCH INFO 2023-02-18 12:54:26,013 host: None
# LAUNCH INFO 2023-02-18 12:54:26,013 ips: None
# LAUNCH INFO 2023-02-18 12:54:26,013 job_id: default
# LAUNCH INFO 2023-02-18 12:54:26,013 legacy: False
# LAUNCH INFO 2023-02-18 12:54:26,013 log_dir: log
# LAUNCH INFO 2023-02-18 12:54:26,013 log_level: INFO
# LAUNCH INFO 2023-02-18 12:54:26,013 master: None
# LAUNCH INFO 2023-02-18 12:54:26,013 max_restart: 3
# LAUNCH INFO 2023-02-18 12:54:26,013 nnodes: 1
# LAUNCH INFO 2023-02-18 12:54:26,013 nproc_per_node: None
# LAUNCH INFO 2023-02-18 12:54:26,013 rank: -1
# LAUNCH INFO 2023-02-18 12:54:26,013 run_mode: collective
# LAUNCH INFO 2023-02-18 12:54:26,013 server_num: None
# ...

# %% [markdown]
# #test

# %%
# !python3 tools/infer_rec.py -c /content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/config.yml -o Global.pretrained_model=/content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/best_accuracy  Global.infer_img=/content/Amin_30979.png
# Out:
# [2023/02/18 13:30:41] ppocr INFO: Architecture :
# [2023/02/18 13:30:41] ppocr INFO:     Backbone :
# [2023/02/18 13:30:41] ppocr INFO:         last_conv_stride : [1, 2]
# [2023/02/18 13:30:41] ppocr INFO:         last_pool_type : avg
# [2023/02/18 13:30:41] ppocr INFO:         name : MobileNetV1Enhance
# [2023/02/18 13:30:41] ppocr INFO:         scale : 0.5
# [2023/02/18 13:30:41] ppocr INFO:     Head :
# [2023/02/18 13:30:41] ppocr INFO:         head_list :
# [2023/02/18 13:30:41] ppocr INFO:             CTCHead :
# [2023/02/18 13:30:41] ppocr INFO:                 Head :
# [2023/02/18 13:30:41] ppocr INFO:                     fc_decay : 1e-05
# [2023/02/18 13:30:41] ppocr INFO:                 Neck :
# [2023/02/18 13:30:41] ppocr INFO:                     depth : 2
# [2023/02/18 13:30:41] ppocr INFO:                     dims : 64
# [2023/02/18 13:30:41] ppocr INFO:                     hidden_dims : 120
# [2023/02/18 13:30:41] ppocr INFO:                     name : svtr
# ...
