# %% [markdown]
# #MOUNT DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Install library

# %%
# !python -m pip install paddlepaddle-gpu==2.4.1.post112 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# %cd /content/PaddleOCR
# !pip install -r requirements.txt

# %%
# !mkdir pretrained_model
# %cd pretrained_model/
# !cp /content/drive/MyDrive/pretrained-model-CRNN/best_accuracy.pdopt -r /content/PaddleOCR/pretrained_model
# !cp /content/drive/MyDrive/pretrained-model-CRNN/best_accuracy.pdparams -r /content/PaddleOCR/pretrained_model
# !cp /content/drive/MyDrive/pretrained-model-CRNN/best_accuracy.states -r /content/PaddleOCR/pretrained_model
# !cp /content/drive/MyDrive/pretrained-model-CRNN/config.yml -r /content/PaddleOCR/pretrained_model
# !cp /content/drive/MyDrive/pretrained-model-CRNN/train.log -r /content/PaddleOCR/pretrained_model
# !wget https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/rec_r34_vd_none_bilstm_ctc_v2.0_train.tar
# !wget https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/rec_mv3_none_bilstm_ctc_v2.0_train.tar
# !tar -xf rec_r34_vd_none_bilstm_ctc_v2.0_train.tar && rm -rf rec_r34_vd_none_bilstm_ctc_v2.0_train.tar
# !tar -xf rec_mv3_none_bilstm_ctc_v2.0_train.tar && rm -rf rec_mv3_none_bilstm_ctc_v2.0_train.tar

# %% [markdown]
# #Removing extra weights in training

# %%
# import glob,pandas,shutil
# files=glob.glob("/content/drive/MyDrive/output_IDPL/*")
# import os
# for file in files:
#   if file.find('676')<=0 and file.find('latest')<=0 and file.find('train')<=0 and file.find('best')<=0 and file.find('config')<=0:
#     os.remove(file)

# %% [markdown]
# #unzip dataset

# %%
# !unzip /content/drive/MyDrive/MY_dataset.zip -d /content/drive/MyDrive

# %%
# !rm -rf /content/drive/MyDrive/MY_dataset

# %%
# !rm -rf /content/drive/MyDrive/output_my_dataset_CRNN
# !rm -rf /content/drive/MyDrive/MY_dataset
# !rm -rf /content/drive/MyDrive/MY_dataset

# %% [markdown]
# #uploading dataset

# %%
# !mkdir /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/shotor-dataset/train-shotor.zip -r /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/shotor-dataset/valdation-shotor.zip -r /content/PaddleOCR/train_data

# %%
# !unzip /content/PaddleOCR/train_data/train-shotor.zip -d /content/PaddleOCR/train_data
# !unzip /content/PaddleOCR/train_data/valdation-shotor.zip -d /content/PaddleOCR/train_data

# %%
# !rm -rf /content/PaddleOCR/train_data/train-shotor.zip
# !rm -rf /content/PaddleOCR/train_data/valdation-shotor.zip

# %%
# !cp /content/drive/MyDrive/shotor-dataset/train-shotor.txt -r /content/PaddleOCR/train_data
# !cp /content/drive/MyDrive/shotor-dataset/valdation-shotor.txt -r /content/PaddleOCR/train_data

# %% [markdown]
# #start train

# %%
import cv2 
import os 
#from imutils import perspective
import numpy as np 
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
from imutils import perspective

# %%
# %cd /content/PaddleOCR
# Out:
# /content/PaddleOCR

# %%
# !cp /content/drive/MyDrive/shotor-dataset/config.yml -r /content/PaddleOCR/pretrained_model/rec_r34_vd_none_bilstm_ctc_v2.0_train

# %%
# !cp /content/PaddleOCR/configs/rec/rec_mv3_none_bilstm_ctc.yml -r /content/PaddleOCR/pretrained_model/rec_mv3_none_bilstm_ctc_v2.0_train

# %%
# !cp /content/PaddleOCR/configs/rec/rec_icdar15_train.yml -r /content/PaddleOCR/pretrained_model/rec_r34_vd_none_bilstm_ctc_v2.0_train

# %%
# !python3 tools/train.py -c /content/PaddleOCR/pretrained_model/rec_mv3_none_bilstm_ctc_v2.0_train/rec_mv3_none_bilstm_ctc.yml -o Global.pretrained_model=/content/PaddleOCR/pretrained_model/rec_mv3_none_bilstm_ctc_v2.0_train/best_accuracy

# %%
# !python3 tools/train.py -c /content/PaddleOCR/pretrained_model/config.yml -o Global.pretrained_model=/content/PaddleOCR/pretrained_model/best_accuracy

# %% [markdown]
# **continue trained model**

# %%
# !python3 tools/train.py -c /content/drive/MyDrive/output_my_dataset_CRNN/v3_arabic_mobile/config.yml -o Global.checkpoints=/content/drive/MyDrive/output_my_dataset_CRNN/v3_arabic_mobile/latest
# Out:
# [2023/02/27 14:40:12] ppocr INFO: Architecture :
# [2023/02/27 14:40:13] ppocr INFO:     Backbone :
# [2023/02/27 14:40:13] ppocr INFO:         model_name : large
# [2023/02/27 14:40:13] ppocr INFO:         name : MobileNetV3
# [2023/02/27 14:40:13] ppocr INFO:         scale : 0.5
# [2023/02/27 14:40:13] ppocr INFO:     Head :
# [2023/02/27 14:40:13] ppocr INFO:         fc_decay : 1e-05
# [2023/02/27 14:40:13] ppocr INFO:         name : CTCHead
# [2023/02/27 14:40:13] ppocr INFO:     Neck :
# [2023/02/27 14:40:13] ppocr INFO:         encoder_type : rnn
# [2023/02/27 14:40:13] ppocr INFO:         hidden_size : 113
# [2023/02/27 14:40:13] ppocr INFO:         name : SequenceEncoder
# [2023/02/27 14:40:13] ppocr INFO:     Transform : None
# [2023/02/27 14:40:13] ppocr INFO:     algorithm : CRNN
# [2023/02/27 14:40:13] ppocr INFO:     model_type : rec
# [2023/02/27 14:40:13] ppocr INFO: Eval :
# [2023/02/27 14:40:13] ppocr INFO:     dataset :
# ...
