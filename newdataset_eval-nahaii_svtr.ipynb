# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python -m pip install paddlepaddle-gpu==2.4.1.post112 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# %cd /content/PaddleOCR
# !pip install -r requirements.txt

# %%
import cv2 
import os 
#from imutils import perspective
import numpy as np 
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
from imutils import perspective

# %%
# %cd /content/PaddleOCR
# Out:
# /content/PaddleOCR

# %% [markdown]
# #**evaluate new-dataset**

# %%
# !python3 -m paddle.distributed.launch --gpus '0' tools/eval.py -c /content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/config.yml -o Global.checkpoints=/content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/best_accuracy
# Out:
# LAUNCH INFO 2023-02-23 07:06:49,335 -----------  Configuration  ----------------------
# LAUNCH INFO 2023-02-23 07:06:49,336 devices: 0
# LAUNCH INFO 2023-02-23 07:06:49,336 elastic_level: -1
# LAUNCH INFO 2023-02-23 07:06:49,336 elastic_timeout: 30
# LAUNCH INFO 2023-02-23 07:06:49,336 gloo_port: 6767
# LAUNCH INFO 2023-02-23 07:06:49,336 host: None
# LAUNCH INFO 2023-02-23 07:06:49,336 ips: None
# LAUNCH INFO 2023-02-23 07:06:49,336 job_id: default
# LAUNCH INFO 2023-02-23 07:06:49,336 legacy: False
# LAUNCH INFO 2023-02-23 07:06:49,336 log_dir: log
# LAUNCH INFO 2023-02-23 07:06:49,336 log_level: INFO
# LAUNCH INFO 2023-02-23 07:06:49,336 master: None
# LAUNCH INFO 2023-02-23 07:06:49,336 max_restart: 3
# LAUNCH INFO 2023-02-23 07:06:49,336 nnodes: 1
# LAUNCH INFO 2023-02-23 07:06:49,336 nproc_per_node: None
# LAUNCH INFO 2023-02-23 07:06:49,336 rank: -1
# LAUNCH INFO 2023-02-23 07:06:49,336 run_mode: collective
# LAUNCH INFO 2023-02-23 07:06:49,336 server_num: None
# ...

# %% [markdown]
# #test

# %%
# !python3 tools/infer_rec.py -c /content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/config.yml -o Global.pretrained_model=/content/drive/MyDrive/output_my_dataset/v3_arabic_mobile/best_accuracy  Global.infer_img=/content/Amin_30992.png
# Out:
# [2023/02/23 07:55:47] ppocr INFO: Architecture :
# [2023/02/23 07:55:47] ppocr INFO:     Backbone :
# [2023/02/23 07:55:47] ppocr INFO:         last_conv_stride : [1, 2]
# [2023/02/23 07:55:47] ppocr INFO:         last_pool_type : avg
# [2023/02/23 07:55:47] ppocr INFO:         name : MobileNetV1Enhance
# [2023/02/23 07:55:47] ppocr INFO:         scale : 0.5
# [2023/02/23 07:55:47] ppocr INFO:     Head :
# [2023/02/23 07:55:47] ppocr INFO:         head_list :
# [2023/02/23 07:55:47] ppocr INFO:             CTCHead :
# [2023/02/23 07:55:47] ppocr INFO:                 Head :
# [2023/02/23 07:55:47] ppocr INFO:                     fc_decay : 1e-05
# [2023/02/23 07:55:47] ppocr INFO:                 Neck :
# [2023/02/23 07:55:47] ppocr INFO:                     depth : 2
# [2023/02/23 07:55:47] ppocr INFO:                     dims : 64
# [2023/02/23 07:55:47] ppocr INFO:                     hidden_dims : 120
# [2023/02/23 07:55:47] ppocr INFO:                     name : svtr
# ...
